# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv('studentsperformance.csv')

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
plt.hist(df['math score'], bins=20)
plt.xlabel('Math Score')
plt.ylabel('Frequency')
plt.title('Histogram of Math Scores')
plt.show()

# %%
sns.boxplot(y='reading score', data=df)
plt.title('Boxplot of Reading Scores')
plt.show()

# %%
sns.scatterplot(x='math score', y='writing score', data=df)
plt.title('Scatter Plot of Math and Writing Scores')
plt.show()

# %%
     sns.barplot(x='race/ethnicity', y='math score', data=df)
plt.title('Bar Plot of Race/Ethnicity and Math Scores')
plt.show()

# %%
corr = df.corr()
sns.heatmap(corr, cmap='coolwarm', annot=True)
plt.title('Heatmap of Correlation Matrix')
plt.show()
